# %% [markdown]
# # Generate Language models from scratch

# %%
from argparse import Namespace

import copy
import glob
import os
import pandas as pd
import pickle
import re
import spacy
from time import time

from gensim.models import Word2Vec
from gensim import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ## Read DB

# %%
db_sentence = pd.read_pickle("./db_trove_v002.pkl")
db_sentence.head()
# Out:
#                                             filePath articleId  \
# 1  ./trove_overproof/datasets/dataset1/rawTextAnd...  18378453
# 2  ./trove_overproof/datasets/dataset1/rawTextAnd...  18363627
# 3  ./trove_overproof/datasets/dataset1/rawTextAnd...  18366055
# 4  ./trove_overproof/datasets/dataset1/rawTextAnd...  18386137
# 5  ./trove_overproof/datasets/dataset1/rawTextAnd...  18368961
#
#             articleType  year  \
# 1  Article ILLUSTRATED   1953
# 2               Article  1953
# 3               Article  1953
# 4               Article  1953
# 5               Article  1953
#
#                                              ocrText  \
# 1  FROM RIVER CROSSING TO END OF TRIÄÜ I ^PI A^H"...
# 2  Natural Childbirth Sir,-We nurses have seen fa...
# 3  FIRST CHURCH I SERVICE 1 Presbyterian I ' Anni...
# 4  "Bob" Lulham's Fight Against Thallium District...
# 5  DIVORCE Before The Judge In Divorce, Mr Justic...
#
#                                            humanText  \
# 1  FROM RIVER CROSSING TO END OF TRIAL SPLASH: Pe...
# 2  Natural Childbirth Sir,-We nurses have seen fa...
# 3  FIRST CHURCH SERVICE Presbyterian Anniversary ...
# 4  "Bob" Lulham's Fight Against Thallium  Arthur ...
# 5  DIVORCE Before The Judge In Divorce, Mr. Justi...
#
#                                            corrected  str_similarity  \
# 1  FROM RIVER CROSSING TO END OF TRIAL SPLASH: Pe...        0.847561
# 2  Natural Childbirth Sir,-We nurses have seen fa...        0.964119
# 3  FIRST CHURCH SERVICE Presbyterian Anniversary ...        0.738901
# 4  "Bob" Lulham's Fight Against Thallium  Arthur ...        0.493898
# 5  DIVORCE Before The Judge In Divorce, Mr. Justi...        0.894176
#
#    str_length_humanText  str_length_ocrText  ...  \
# 1                   746                 820  ...
# 2                   641                 630  ...
# 3                   946                 832  ...
# 4                  2950                2740  ...
# 5                  1219                1121  ...
#
#                                corrected_dict_lookup  \
# 1  [[4, 5, 8, 2, 3, 2, 5, 6, 1, -5, -6, 8, 4, 4, ...
# 2  [[7, 10, -7, 6, 4, 4, 3, 3, 4, 5, 6, 4, 6, 5, ...
# 3  [[5, 6, 7, 12, 11, 3, 5, 11, 2, 3, 5, 12, 6, 7...
# 4  [[1, 3, 1, -6, 2, 5, 7, 8, 6, 6, 1, 1, 3, 1, 1...
# 5  [[7, 6, 3, 5, 2, 7, 1, 2, 1, 7, -5, 7, 4, 1, 1...
#
#                                      ocr_sentencizer  \
# 1  [[FROM, RIVER, CROSSING, TO, END, OF, TRIÄÜ, I...
# 2  [[Natural, Childbirth, Sir,-We, nurses, have, ...
# 3  [[FIRST, CHURCH, I, SERVICE, 1, Presbyterian, ...
# 4  [[", Bob, ", Lulham, 's, Fight, Against, Thall...
# 5  [[DIVORCE, Before, The, Judge, In, Divorce, ,,...
#
#                                      ocr_dict_lookup  \
# 1  [[4, 5, 8, 2, 3, 2, -5, 1, 1, 2, -3, 1, -5, -6...
# 2  [[7, 10, -7, 6, 4, 4, 3, 3, 4, 5, 6, 4, 6, 5, ...
# 3  [[5, 6, 1, 7, 1, 12, 1, 1, 11, 1, 3, 5, -12, 3...
# 4  [[1, 3, 1, -6, 2, 5, 7, 8, 8, 8, 1], [4, 5, 6,...
# 5  [[7, 6, 3, 5, 2, 7, 1, 2, 7, -5, 7, 4, 1, 1, -...
#
#                                 ocr_dict_lookup_list ocr_dict_perc  \
# 1  [4, 5, 8, 2, 3, 2, -5, 1, 1, 2, -3, 1, -5, -6,...     79.439252
# 2  [7, 10, -7, 6, 4, 4, 3, 3, 4, 5, 6, 4, 6, 5, 2...     96.590909
# 3  [5, 6, 1, 7, 1, 12, 1, 1, 11, 1, 3, 5, -12, 3,...     82.000000
# 4  [1, 3, 1, -6, 2, 5, 7, 8, 8, 8, 1, 4, 5, 6, 6,...     95.580110
# 5  [7, 6, 3, 5, 2, 7, 1, 2, 7, -5, 7, 4, 1, 1, -6...     82.882883
#
#                           corrected_dict_lookup_list corr_dict_perc  \
# 1  [4, 5, 8, 2, 3, 2, 5, 6, 1, -5, -6, 8, 4, 4, 5...      92.079208
# 2  [7, 10, -7, 6, 4, 4, 3, 3, 4, 5, 6, 4, 6, 5, 2...      98.876404
# 3  [5, 6, 7, 12, 11, 3, 5, 11, 2, 3, 5, 12, 6, 7,...      99.206349
# 4  [1, 3, 1, -6, 2, 5, 7, 8, 6, 6, 1, 1, 3, 1, 1,...      95.652174
# 5  [7, 6, 3, 5, 2, 7, 1, 2, 1, 7, -5, 7, 4, 1, 1,...      86.486486
#
#                           corrected_sentencizer_list  \
# 1  [FROM, RIVER, CROSSING, TO, END, OF, TRIAL, SP...
# 2  [Natural, Childbirth, Sir,-We, nurses, have, s...
# 3  [FIRST, CHURCH, SERVICE, Presbyterian, Anniver...
# 4  [", Bob, ", Lulham, 's, Fight, Against, Thalli...
# 5  [DIVORCE, Before, The, Judge, In, Divorce, ,, ...
#
#                                 ocr_sentencizer_list  jaccard_similarity
# 1  [FROM, RIVER, CROSSING, TO, END, OF, TRIÄÜ, I,...            0.305882
# 2  [Natural, Childbirth, Sir,-We, nurses, have, s...            0.523810
# 3  [FIRST, CHURCH, I, SERVICE, 1, Presbyterian, I...            0.191919
# 4  [", Bob, ", Lulham, 's, Fight, Against, Thalli...            0.282682
# 5  [DIVORCE, Before, The, Judge, In, Divorce, ,, ...            0.147513
#
# [5 rows x 23 columns]

# %% [markdown]
# ## preprocess DB

# %%
def cleanup(myrow, col_name):
    all_clean_rows = []
    for sent in myrow[col_name]:
        one_clean_row = []
        for token in sent:
            one_clean_row.append(token.lower())
        all_clean_rows.append(one_clean_row)
    return all_clean_rows

# %%
db_sentence["ocr_sentencizer_cleaned"] = db_sentence.apply(cleanup, args=["ocr_sentencizer"], axis=1)
db_sentence["corrected_sentencizer_cleaned"] = db_sentence.apply(cleanup, args=["corrected_sentencizer"], axis=1)

# %%
db_sentence.head()
# Out:
#                                             filePath articleId  \
# 1  ./trove_overproof/datasets/dataset1/rawTextAnd...  18378453
# 2  ./trove_overproof/datasets/dataset1/rawTextAnd...  18363627
# 3  ./trove_overproof/datasets/dataset1/rawTextAnd...  18366055
# 4  ./trove_overproof/datasets/dataset1/rawTextAnd...  18386137
# 5  ./trove_overproof/datasets/dataset1/rawTextAnd...  18368961
#
#             articleType  year  \
# 1  Article ILLUSTRATED   1953
# 2               Article  1953
# 3               Article  1953
# 4               Article  1953
# 5               Article  1953
#
#                                              ocrText  \
# 1  FROM RIVER CROSSING TO END OF TRIÄÜ I ^PI A^H"...
# 2  Natural Childbirth Sir,-We nurses have seen fa...
# 3  FIRST CHURCH I SERVICE 1 Presbyterian I ' Anni...
# 4  "Bob" Lulham's Fight Against Thallium District...
# 5  DIVORCE Before The Judge In Divorce, Mr Justic...
#
#                                            humanText  \
# 1  FROM RIVER CROSSING TO END OF TRIAL SPLASH: Pe...
# 2  Natural Childbirth Sir,-We nurses have seen fa...
# 3  FIRST CHURCH SERVICE Presbyterian Anniversary ...
# 4  "Bob" Lulham's Fight Against Thallium  Arthur ...
# 5  DIVORCE Before The Judge In Divorce, Mr. Justi...
#
#                                            corrected  str_similarity  \
# 1  FROM RIVER CROSSING TO END OF TRIAL SPLASH: Pe...        0.847561
# 2  Natural Childbirth Sir,-We nurses have seen fa...        0.964119
# 3  FIRST CHURCH SERVICE Presbyterian Anniversary ...        0.738901
# 4  "Bob" Lulham's Fight Against Thallium  Arthur ...        0.493898
# 5  DIVORCE Before The Judge In Divorce, Mr. Justi...        0.894176
#
#    str_length_humanText  str_length_ocrText  ...  \
# 1                   746                 820  ...
# 2                   641                 630  ...
# 3                   946                 832  ...
# 4                  2950                2740  ...
# 5                  1219                1121  ...
#
#                                      ocr_dict_lookup  \
# 1  [[4, 5, 8, 2, 3, 2, -5, 1, 1, 2, -3, 1, -5, -6...
# 2  [[7, 10, -7, 6, 4, 4, 3, 3, 4, 5, 6, 4, 6, 5, ...
# 3  [[5, 6, 1, 7, 1, 12, 1, 1, 11, 1, 3, 5, -12, 3...
# 4  [[1, 3, 1, -6, 2, 5, 7, 8, 8, 8, 1], [4, 5, 6,...
# 5  [[7, 6, 3, 5, 2, 7, 1, 2, 7, -5, 7, 4, 1, 1, -...
#
#                                 ocr_dict_lookup_list ocr_dict_perc  \
# 1  [4, 5, 8, 2, 3, 2, -5, 1, 1, 2, -3, 1, -5, -6,...     79.439252
# 2  [7, 10, -7, 6, 4, 4, 3, 3, 4, 5, 6, 4, 6, 5, 2...     96.590909
# 3  [5, 6, 1, 7, 1, 12, 1, 1, 11, 1, 3, 5, -12, 3,...     82.000000
# 4  [1, 3, 1, -6, 2, 5, 7, 8, 8, 8, 1, 4, 5, 6, 6,...     95.580110
# 5  [7, 6, 3, 5, 2, 7, 1, 2, 7, -5, 7, 4, 1, 1, -6...     82.882883
#
#                           corrected_dict_lookup_list corr_dict_perc  \
# 1  [4, 5, 8, 2, 3, 2, 5, 6, 1, -5, -6, 8, 4, 4, 5...      92.079208
# 2  [7, 10, -7, 6, 4, 4, 3, 3, 4, 5, 6, 4, 6, 5, 2...      98.876404
# 3  [5, 6, 7, 12, 11, 3, 5, 11, 2, 3, 5, 12, 6, 7,...      99.206349
# 4  [1, 3, 1, -6, 2, 5, 7, 8, 6, 6, 1, 1, 3, 1, 1,...      95.652174
# 5  [7, 6, 3, 5, 2, 7, 1, 2, 1, 7, -5, 7, 4, 1, 1,...      86.486486
#
#                           corrected_sentencizer_list  \
# 1  [FROM, RIVER, CROSSING, TO, END, OF, TRIAL, SP...
# 2  [Natural, Childbirth, Sir,-We, nurses, have, s...
# 3  [FIRST, CHURCH, SERVICE, Presbyterian, Anniver...
# 4  [", Bob, ", Lulham, 's, Fight, Against, Thalli...
# 5  [DIVORCE, Before, The, Judge, In, Divorce, ,, ...
#
#                                 ocr_sentencizer_list  jaccard_similarity  \
# 1  [FROM, RIVER, CROSSING, TO, END, OF, TRIÄÜ, I,...            0.305882
# 2  [Natural, Childbirth, Sir,-We, nurses, have, s...            0.523810
# 3  [FIRST, CHURCH, I, SERVICE, 1, Presbyterian, I...            0.191919
# 4  [", Bob, ", Lulham, 's, Fight, Against, Thalli...            0.282682
# 5  [DIVORCE, Before, The, Judge, In, Divorce, ,, ...            0.147513
#
#                              ocr_sentencizer_cleaned  \
# 1  [[from, river, crossing, to, end, of, triäü, i...
# 2  [[natural, childbirth, sir,-we, nurses, have, ...
# 3  [[first, church, i, service, 1, presbyterian, ...
# 4  [[", bob, ", lulham, 's, fight, against, thall...
# 5  [[divorce, before, the, judge, in, divorce, ,,...
#
#                        corrected_sentencizer_cleaned
# 1  [[from, river, crossing, to, end, of, trial, s...
# 2  [[natural, childbirth, sir,-we, nurses, have, ...
# 3  [[first, church, service, presbyterian, annive...
# 4  [[", bob, ", lulham, 's, fight, against, thall...
# 5  [[divorce, before, the, judge, in, divorce, ,,...
#
# [5 rows x 25 columns]

# %% [markdown]
# ## LM parameters

# %%
# args for Word2Vec
w2v_args = Namespace(
    epochs=5, 
    # only for Word2Vec
    compute_loss=True,                               # If True, computes and stores loss value which can be retrieved using get_latest_training_loss().

    size=300,                                        # Dimensionality of the word vectors.
    alpha=0.03,                                      # The initial learning rate.
    min_alpha=0.0007,                                # Learning rate will linearly drop to min_alpha as training progresses.
    sg=1,                                            # Training algorithm: skip-gram if sg=1, otherwise CBOW.
    hs=0,                                            # If 1, hierarchical softmax will be used for model training. If set to 0, and negative is non-zero, negative sampling will be used.
    negative=20,                                     # If > 0, negative sampling will be used, the int for negative specifies how many “noise words” should be drawn (usually between 5-20). If set to 0, no negative sampling is used. 
    min_count=0,                                   # The model ignores all words with total frequency lower than this.
    window=5,                                        # The maximum distance between the current and predicted word within a sentence.
    sample=1e-3,                                     # The threshold for configuring which higher-frequency words are randomly downsampled, useful range is (0, 1e-5).
    workers=8, 
    cbow_mean=1,                                     # If 0, use the sum of the context word vectors. If 1, use the mean, only applies when cbow is used.
    null_word=0,                                     # 
    trim_rule=None,                                  # 
    sorted_vocab=1,                                  # If 1, sort the vocabulary by descending frequency before assigning word indices.
    batch_words=10000,                               # Target size (in words) for batches of examples passed to worker threads (and thus cython routines).(Larger batches will be passed if individual texts are longer than 10000 words, but the standard cython code truncates to that maximum.)
    
    seed=1364,                                       # Seed for the random number generator.
    # only for FastText (compare to word2vec)
    #word_ngrams=1,                                   # If 1, uses enriches word vectors with subword(n-grams) information. If 0, this is equivalent to Word2Vec. 
    #min_n=2,                                         # Minimum length of char n-grams to be used for training word representations.
    #max_n=15,                                        # Max length of char ngrams to be used for training word representations. Set max_n to be lesser than min_n to avoid char ngrams being used.
    #bucket=2000000                                  # Character ngrams are hashed into a fixed number of buckets, in order to limit the memory usage of the model. This option specifies the number of buckets used by the model.
)

# %%
# Only if a new LM needs to be trained (from scratch)
embedding_model_ocr = Word2Vec(
     size=w2v_args.size, 
     alpha=w2v_args.alpha,
     min_alpha=w2v_args.min_alpha, 
     sg=w2v_args.sg, 
     hs=w2v_args.hs, 
     negative=w2v_args.negative, 
     iter=w2v_args.epochs, 
     min_count=w2v_args.min_count, 
     window=w2v_args.window, 
     sample=w2v_args.sample, 
     workers=w2v_args.workers, 
     cbow_mean=w2v_args.cbow_mean, 
     null_word=w2v_args.null_word, 
     trim_rule=w2v_args.trim_rule, 
     sorted_vocab=w2v_args.sorted_vocab, 
     batch_words=w2v_args.batch_words, 
     seed=w2v_args.seed, 
     compute_loss=w2v_args.compute_loss)

# Only if a new LM needs to be trained (from scratch)
embedding_model_corrected = Word2Vec(
     size=w2v_args.size, 
     alpha=w2v_args.alpha,
     min_alpha=w2v_args.min_alpha, 
     sg=w2v_args.sg, 
     hs=w2v_args.hs, 
     negative=w2v_args.negative, 
     iter=w2v_args.epochs, 
     min_count=w2v_args.min_count, 
     window=w2v_args.window, 
     sample=w2v_args.sample, 
     workers=w2v_args.workers, 
     cbow_mean=w2v_args.cbow_mean, 
     null_word=w2v_args.null_word, 
     trim_rule=w2v_args.trim_rule, 
     sorted_vocab=w2v_args.sorted_vocab, 
     batch_words=w2v_args.batch_words, 
     seed=w2v_args.seed, 
     compute_loss=w2v_args.compute_loss)

# %% [markdown]
# ## Preprocess before creating/updating LM

# %%
"""
def preprocess4LM(myrow, col_name="ocrText_cleaned_tokenize"):
    txt = [token.lemma_ for token in nlp(myrow[col_name].lower())]
    return txt
"""

# %%
"""
db_sentence["ocrText_cleaned_tokenize"] = db_sentence[0:10].apply(preprocess4LM, args=["ocrText_cleaned"], axis=1)
db_sentence["corrected_cleaned_tokenize"] = db_sentence[0:10].apply(preprocess4LM, args=["corrected_cleaned"], axis=1)
"""

# %% [markdown]
# ## OCR

# %%
list_sentences = db_sentence["ocr_sentencizer_cleaned"].to_list()
print('#sentences: {}'.format(len(list_sentences)))

# %%
flattened_list_sentences = [val for sublist in list_sentences for val in sublist]

# %%
flattened_list_sentences[0]

# %%
embedding_model_ocr.build_vocab(flattened_list_sentences)
embedding_model_ocr.train(flattened_list_sentences, 
                          total_examples=embedding_model_ocr.corpus_count,
                          epochs=w2v_args.epochs,  
                          compute_loss=w2v_args.compute_loss)

# %%
print("\n\n[INFO] Save the model")
embedding_model_ocr.save("./embedding_model_ocr.model")

# %% [markdown]
# ## Corrected

# %%
list_sentences = db_sentence["corrected_sentencizer_cleaned"].to_list()
print('#sentences: {}'.format(len(list_sentences)))
# Out:
# #sentences: 30509

# %%
flattened_list_sentences = [val for sublist in list_sentences for val in sublist]

# %%
flattened_list_sentences[0]
# Out:
# ['from',
#  'river',
#  'crossing',
#  'to',
#  'end',
#  'of',
#  'trial',
#  'splash',
#  ':',
#  'peler',
#  'antill',
#  'ploughed',
#  'deep',
#  'into',
#  'paddy',
#  "'s",
#  'river',
#  'in',
#  'his',
#  'chrysler',
#  'plymouth',
#  'during',
#  'the',
#  'elimination',
#  'section',
#  '.']

# %%
len(flattened_list_sentences)
# Out:
# 499269

# %%
embedding_model_corrected.build_vocab(flattened_list_sentences)
embedding_model_corrected.train(flattened_list_sentences, 
                                total_examples=embedding_model_corrected.corpus_count,
                                epochs=w2v_args.epochs,  
                                compute_loss=w2v_args.compute_loss)
# Out:
# 2019-11-20 19:38:08,751 : INFO : collecting all words and their counts
# 2019-11-20 19:38:08,753 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-11-20 19:38:08,854 : INFO : PROGRESS: at sentence #10000, processed 238920 words, keeping 21363 word types
# 2019-11-20 19:38:08,958 : INFO : PROGRESS: at sentence #20000, processed 462924 words, keeping 30432 word types
# 2019-11-20 19:38:09,073 : INFO : PROGRESS: at sentence #30000, processed 706176 words, keeping 39228 word types
# 2019-11-20 19:38:09,218 : INFO : PROGRESS: at sentence #40000, processed 967747 words, keeping 46390 word types
# 2019-11-20 19:38:09,377 : INFO : PROGRESS: at sentence #50000, processed 1206328 words, keeping 52319 word types
# 2019-11-20 19:38:09,558 : INFO : PROGRESS: at sentence #60000, processed 1454073 words, keeping 57131 word types
# 2019-11-20 19:38:09,742 : INFO : PROGRESS: at sentence #70000, processed 1709317 words, keeping 61561 word types
# 2019-11-20 19:38:09,933 : INFO : PROGRESS: at sentence #80000, processed 1953711 words, keeping 66452 word types
# 2019-11-20 19:38:10,086 : INFO : PROGRESS: at sentence #90000, processed 2193623 words, keeping 70605 word types
# 2019-11-20 19:38:10,231 : INFO : PROGRESS: at sentence #100000, processed 2442433 words, keeping 74867 word types
# 2019-11-20 19:38:10,427 : INFO : PROGRESS: at sentence #110000, processed 2714060 words, keeping 78874 word types
# 2019-11-20 19:38:10,577 : INFO : PROGRESS: at sentence #120000, processed 2958402 words, keeping 82525 word types
# 2019-11-20 19:38:10,728 : INFO : PROGRESS: at sentence #130000, processed 3188124 words, keeping 85969 word types
# 2019-11-20 19:38:10,879 : INFO : PROGRESS: at sentence #140000, processed 3437823 words, keeping 89967 word types
# 2019-11-20 19:38:11,033 : INFO : PROGRESS: at sentence #150000, processed 3695828 words, keeping 94014 word types
# 2019-11-20 19:38:11,183 : INFO : PROGRESS: at sentence #160000, processed 3941960 words, keeping 97060 word types
# 2019-11-20 19:38:11,330 : INFO : PROGRESS: at sentence #170000, processed 4173711 words, keeping 100500 word types
# 2019-11-20 19:38:11,473 : INFO : PROGRESS: at sentence #180000, processed 4407953 words, keeping 103674 word types
# 2019-11-20 19:38:11,625 : INFO : PROGRESS: at sentence #190000, processed 4653900 words, keeping 106938 word types
# 2019-11-20 19:38:11,782 : INFO : PROGRESS: at sentence #200000, processed 4894380 words, keeping 109826 word types
# 2019-11-20 19:38:11,929 : INFO : PROGRESS: at sentence #210000, processed 5143048 words, keeping 112348 word types
# 2019-11-20 19:38:12,095 : INFO : PROGRESS: at sentence #220000, processed 5407809 words, keeping 116127 word types
# 2019-11-20 19:38:12,235 : INFO : PROGRESS: at sentence #230000, processed 5632256 words, keeping 118732 word types
# 2019-11-20 19:38:12,385 : INFO : PROGRESS: at sentence #240000, processed 5857441 words, keeping 121618 word types
# 2019-11-20 19:38:12,517 : INFO : PROGRESS: at sentence #250000, processed 6071938 words, keeping 123752 word types
# 2019-11-20 19:38:12,653 : INFO : PROGRESS: at sentence #260000, processed 6302770 words, keeping 126469 word types
# 2019-11-20 19:38:12,818 : INFO : PROGRESS: at sentence #270000, processed 6555040 words, keeping 129136 word types
# 2019-11-20 19:38:12,986 : INFO : PROGRESS: at sentence #280000, processed 6802156 words, keeping 131406 word types
# 2019-11-20 19:38:13,156 : INFO : PROGRESS: at sentence #290000, processed 7036644 words, keeping 133727 word types
# 2019-11-20 19:38:13,309 : INFO : PROGRESS: at sentence #300000, processed 7259334 words, keeping 136544 word types
# 2019-11-20 19:38:13,482 : INFO : PROGRESS: at sentence #310000, processed 7496943 words, keeping 139064 word types
# 2019-11-20 19:38:13,634 : INFO : PROGRESS: at sentence #320000, processed 7746685 words, keeping 141765 word types
# 2019-11-20 19:38:13,799 : INFO : PROGRESS: at sentence #330000, processed 7982859 words, keeping 143854 word types
# 2019-11-20 19:38:13,942 : INFO : PROGRESS: at sentence #340000, processed 8213783 words, keeping 145598 word types
# 2019-11-20 19:38:14,109 : INFO : PROGRESS: at sentence #350000, processed 8475485 words, keeping 148076 word types
# 2019-11-20 19:38:14,276 : INFO : PROGRESS: at sentence #360000, processed 8710121 words, keeping 150482 word types
# 2019-11-20 19:38:14,391 : INFO : PROGRESS: at sentence #370000, processed 8941968 words, keeping 152372 word types
# 2019-11-20 19:38:14,488 : INFO : PROGRESS: at sentence #380000, processed 9193157 words, keeping 154924 word types
# 2019-11-20 19:38:14,565 : INFO : PROGRESS: at sentence #390000, processed 9426266 words, keeping 156789 word types
# 2019-11-20 19:38:14,644 : INFO : PROGRESS: at sentence #400000, processed 9684734 words, keeping 159635 word types
# 2019-11-20 19:38:14,891 : INFO : PROGRESS: at sentence #410000, processed 9911276 words, keeping 161735 word types
# 2019-11-20 19:38:15,029 : INFO : PROGRESS: at sentence #420000, processed 10141232 words, keeping 163536 word types
# 2019-11-20 19:38:15,167 : INFO : PROGRESS: at sentence #430000, processed 10383723 words, keeping 165716 word types
# 2019-11-20 19:38:15,319 : INFO : PROGRESS: at sentence #440000, processed 10622947 words, keeping 168137 word types
# 2019-11-20 19:38:15,483 : INFO : PROGRESS: at sentence #450000, processed 10897590 words, keeping 170776 word types
# 2019-11-20 19:38:15,633 : INFO : PROGRESS: at sentence #460000, processed 11139912 words, keeping 172884 word types
# 2019-11-20 19:38:15,784 : INFO : PROGRESS: at sentence #470000, processed 11392785 words, keeping 174354 word types
# 2019-11-20 19:38:15,970 : INFO : PROGRESS: at sentence #480000, processed 11643314 words, keeping 175435 word types
# 2019-11-20 19:38:16,125 : INFO : PROGRESS: at sentence #490000, processed 11885014 words, keeping 176881 word types
# 2019-11-20 19:38:16,301 : INFO : collected 179735 word types from a corpus of 12124087 raw words and 499269 sentences
# 2019-11-20 19:38:16,302 : INFO : Loading a fresh vocabulary
# 2019-11-20 19:38:17,180 : INFO : effective_min_count=0 retains 179735 unique words (100% of original 179735, drops 0)
# 2019-11-20 19:38:17,182 : INFO : effective_min_count=0 leaves 12124087 word corpus (100% of original 12124087, drops 0)
# 2019-11-20 19:38:18,630 : INFO : deleting the raw counts dictionary of 179735 items
# 2019-11-20 19:38:18,640 : INFO : sample=0.001 downsamples 34 most-common words
# 2019-11-20 19:38:18,643 : INFO : downsampling leaves estimated 8409881 word corpus (69.4% of prior 12124087)
# 2019-11-20 19:38:19,832 : INFO : estimated required memory for 179735 words and 300 dimensions: 521231500 bytes
# 2019-11-20 19:38:19,839 : INFO : resetting layer weights
# 2019-11-20 19:39:18,682 : INFO : training model with 8 workers on 179735 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=20 window=5
# 2019-11-20 19:39:19,779 : INFO : EPOCH 1 - PROGRESS: at 0.72% examples, 62933 words/s, in_qsize 14, out_qsize 1
# 2019-11-20 19:39:20,861 : INFO : EPOCH 1 - PROGRESS: at 2.10% examples, 84937 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:39:21,901 : INFO : EPOCH 1 - PROGRESS: at 3.57% examples, 93401 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:39:23,228 : INFO : EPOCH 1 - PROGRESS: at 5.51% examples, 102877 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:39:24,249 : INFO : EPOCH 1 - PROGRESS: at 6.84% examples, 103769 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:39:25,479 : INFO : EPOCH 1 - PROGRESS: at 8.01% examples, 101230 words/s, in_qsize 16, out_qsize 0
# 2019-11-20 19:39:26,495 : INFO : EPOCH 1 - PROGRESS: at 9.09% examples, 99510 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:39:27,671 : INFO : EPOCH 1 - PROGRESS: at 9.35% examples, 88693 words/s, in_qsize 14, out_qsize 2
# 2019-11-20 19:39:28,899 : INFO : EPOCH 1 - PROGRESS: at 10.02% examples, 83362 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:39:30,254 : INFO : EPOCH 1 - PROGRESS: at 10.65% examples, 78334 words/s, in_qsize 14, out_qsize 1
# 2019-11-20 19:39:31,305 : INFO : EPOCH 1 - PROGRESS: at 11.32% examples, 76146 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:39:32,359 : INFO : EPOCH 1 - PROGRESS: at 11.96% examples, 74313 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:39:33,393 : INFO : EPOCH 1 - PROGRESS: at 12.58% examples, 72845 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:39:34,445 : INFO : EPOCH 1 - PROGRESS: at 13.38% examples, 71885 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:39:35,529 : INFO : EPOCH 1 - PROGRESS: at 13.93% examples, 70552 words/s, in_qsize 16, out_qsize 0
# 2019-11-20 19:39:36,544 : INFO : EPOCH 1 - PROGRESS: at 14.64% examples, 70009 words/s, in_qsize 16, out_qsize 0
# 2019-11-20 19:39:37,583 : INFO : EPOCH 1 - PROGRESS: at 15.40% examples, 69409 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:39:38,597 : INFO : EPOCH 1 - PROGRESS: at 15.96% examples, 68261 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:39:39,598 : INFO : EPOCH 1 - PROGRESS: at 16.63% examples, 67614 words/s, in_qsize 14, out_qsize 1
# 2019-11-20 19:39:40,638 : INFO : EPOCH 1 - PROGRESS: at 17.32% examples, 66945 words/s, in_qsize 16, out_qsize 1
# 2019-11-20 19:39:41,675 : INFO : EPOCH 1 - PROGRESS: at 18.22% examples, 67193 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:39:42,717 : INFO : EPOCH 1 - PROGRESS: at 18.91% examples, 66545 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:39:43,740 : INFO : EPOCH 1 - PROGRESS: at 19.58% examples, 66315 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:39
words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:49:58,879 : INFO : EPOCH 5 - PROGRESS: at 89.21% examples, 66568 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:50:00,082 : INFO : EPOCH 5 - PROGRESS: at 89.80% examples, 66349 words/s, in_qsize 16, out_qsize 0
# 2019-11-20 19:50:01,145 : INFO : EPOCH 5 - PROGRESS: at 90.41% examples, 66219 words/s, in_qsize 16, out_qsize 0
# 2019-11-20 19:50:02,283 : INFO : EPOCH 5 - PROGRESS: at 91.08% examples, 66039 words/s, in_qsize 15, out_qsize 1
# 2019-11-20 19:50:03,308 : INFO : EPOCH 5 - PROGRESS: at 91.65% examples, 65872 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:50:04,433 : INFO : EPOCH 5 - PROGRESS: at 92.32% examples, 65707 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:50:05,600 : INFO : EPOCH 5 - PROGRESS: at 92.99% examples, 65522 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:50:06,809 : INFO : EPOCH 5 - PROGRESS: at 93.62% examples, 65323 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:50:07,889 : INFO : EPOCH 5 - PROGRESS: at 94.22% examples, 65200 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:50:09,012 : INFO : EPOCH 5 - PROGRESS: at 94.87% examples, 65051 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:50:10,320 : INFO : EPOCH 5 - PROGRESS: at 95.47% examples, 64812 words/s, in_qsize 15, out_qsize 1
# 2019-11-20 19:50:11,545 : INFO : EPOCH 5 - PROGRESS: at 96.12% examples, 64616 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:50:12,756 : INFO : EPOCH 5 - PROGRESS: at 96.81% examples, 64433 words/s, in_qsize 16, out_qsize 1
# 2019-11-20 19:50:13,834 : INFO : EPOCH 5 - PROGRESS: at 97.47% examples, 64320 words/s, in_qsize 15, out_qsize 0
# 2019-11-20 19:50:14,961 : INFO : EPOCH 5 - PROGRESS: at 98.12% examples, 64188 words/s, in_qsize 14, out_qsize 1
# 2019-11-20 19:50:16,048 : INFO : EPOCH 5 - PROGRESS: at 98.80% examples, 64083 words/s, in_qsize 14, out_qsize 1
# 2019-11-20 19:50:17,235 : INFO : EPOCH 5 - PROGRESS: at 99.46% examples, 63924 words/s, in_qsize 9, out_qsize 0
# 2019-11-20 19:50:17,267 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-20 19:50:17,524 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-20 19:50:17,627 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-20 19:50:17,752 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-20 19:50:17,897 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-20 19:50:17,920 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-20 19:50:17,956 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-20 19:50:18,261 : INFO : EPOCH 5 - PROGRESS: at 100.00% examples, 63883 words/s, in_qsize 0, out_qsize 1
# 2019-11-20 19:50:18,262 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-20 19:50:18,263 : INFO : EPOCH - 5 : training on 12124087 raw words (8409105 effective words) took 131.6s, 63882 effective words/s
# 2019-11-20 19:50:18,265 : INFO : training on a 60620435 raw words (42047385 effective words) took 659.6s, 63751 effective words/s
# (42047385, 60620435)

# %%
print("\n\n[INFO] Save the model")
embedding_model_corrected.save("./embedding_model_scratch_corrected.model")
# Out:
# 2019-11-20 19:50:18,394 : INFO : saving Word2Vec object under ./embedding_model_scratch_corrected.model, separately None
# 2019-11-20 19:50:18,413 : INFO : storing np array 'vectors' to ./embedding_model_scratch_corrected.model.wv.vectors.npy
# [INFO] Save the model
# 2019-11-20 19:50:19,664 : INFO : not storing attribute vectors_norm
# 2019-11-20 19:50:19,703 : INFO : storing np array 'syn1neg' to ./embedding_model_scratch_corrected.model.trainables.syn1neg.npy
# 2019-11-20 19:50:21,165 : INFO : not storing attribute cum_table
# 2019-11-20 19:50:22,341 : INFO : saved ./embedding_model_scratch_corrected.model
