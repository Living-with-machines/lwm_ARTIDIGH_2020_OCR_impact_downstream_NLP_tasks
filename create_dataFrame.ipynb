# %% [markdown]
# # Create a DataFrame out of selected directories

# %%
import argparse
from glob import glob
import numpy as np
import os
from pathlib import Path
import pandas as pd
import re
import spacy
import syntok.segmenter as segmenter
import string
import sys

# %%
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# **Impacts of OCR quality on indexing, accessing and retrievability of digital documents**
#
# The corpus accounts for 22M (only 2019 dataset) OCRed characters along with the corresponding Gold Standard (GS) which has been aligned at the character level.
#
# <img src="./images/ICDAR_symbols.png">
#
# The aligned OCRed/GS texts are provided for training and test purposes. The alignment was made at the character level using "@" symbols. "#" symbols correspond to the absence of GS either related to alignment uncertainties or related to unreadable characters in the source document.
#
# The Error Rate and the quality of the alignment vary according to the nature and the state of degradation of the source documents. Periodicals (mostly historical newspapers) for example, due to their complex layout and their original fonts have been reported to be especially challenging. In addition, **it should be mentioned that the quality of Gold Standard also varies as the dataset aggregates resources from different projects that have their own annotation procedure, and obviously contains some errors.**
#
#
# Important notice, in the archive :
#
# * Even ids (document numbers) were exclusively used for Task 1) Detection
# * Odd ids (document numbers) were exclusively used for Task 2) Correction

# %%
# Dictionary with the following structure:
# arbitrary_dirname: path_to_txt_files
# "arbitrary_dirname" is an arbitrary name which can be used to filter the DB in later steps

dict_dirnames = {
    "eng_monograph_2017": './ICDAR2017_datasetPostOCR_v1.2/ICDAR2017_datasetPostOCR_Full_12M_v1.2/eng_monograph',
    "eng_periodical_2017": './ICDAR2017_datasetPostOCR_v1.2/ICDAR2017_datasetPostOCR_Full_12M_v1.2/eng_periodical',
    "en1_2019": './ICDAR2019_POCR_competition_dataset/ICDAR2019_POCR_competition_full_22M_without_Finnish/EN/EN1'
}

# %%
db = pd.DataFrame(columns=["index", "OCR_toInput", "OCR_aligned", "GS_aligned", "dirname"])

# %%
row_counter = 0
for ldir in dict_dirnames.keys():
    list_files = glob(os.path.join(dict_dirnames[ldir], "*.txt"))
    for lfile in list_files:   
        fio = open(lfile, "r")
        fread = fio.readlines()
        db.loc[row_counter] = [int(os.path.basename(lfile).split(".txt")[0]), 
                               fread[0].split("[OCR_toInput]")[1],
                               fread[1].split("[OCR_aligned]")[1],
                               fread[2].split("[ GS_aligned]")[1],
                               ldir
                              ]    
        row_counter += 1

# %%
print("Length before removing duplicates: {}".format(len(db)))
print(10*"=")
print("Duplicate rows:")
db[db.duplicated("OCR_toInput")]
# Out:
# Length before removing duplicates: 963
# ==========
# Duplicate rows:
#     index                                        OCR_toInput  \
# 889   141   10* THE CHEATS OF SCAPIN. Scapin. Well,. Sir,...
# 893    82   The PREFACE. Is the Souls of all Mankind be c...
# 894   140   betwixt our condition, and that of the Heathe...
# 918   147   (toy jkilfull mattthe learning of the Ægyptia...
# 919   146   huisstm head, for, the, cross is left v in hi...
# 927   135   PREFACE. VU Abp. Trench could tell us nothing...
# 929   109                                                ■\n
# 932   134   [8*3 shutting out and Retraction of the fen- ...
# 933    21   Jcadmu Sckntkrum. v 19 Secttio Tertia. Aftrol...
# 938   136   24 CBA%ACTE\S An vnvortbie Knight. i$« 9 1 4 ...
# 939   137   (%) ' when one is sued, by occasion of Tutors...
# 948   126   SECT. I.] THE ISLES OF GREECE. 4+3 CCCXLIV. T...
#
#                                            OCR_aligned  \
# 889   10* THE CHEATS OF SCAPIN. Scapin. Well,. Sir,...
# 893   @The PREFACE. Is the Souls of all Mankind be ...
# 894   @@@@@@@@betwixt our condition, and that of th...
# 918   @(toy jkilfull @@ma@ttthe learning of the Ægy...
# 919   @@@@@huisstm head, for, the, cross is left v ...
# 927   @PREFACE. @VU Abp. Trench could tell us nothi...
# 929                                                ■\n
# 932   @[@8@@@@@*3 shutting out and Retraction of th...
# 933   Jcadmu Sckntkrum. v 19 Secttio Tertia. Aftrol...
# 938   @24 CBA%ACTE\S An vnvortbie Knight@@@@.@@@@@@...
# 939   @(@%) ' when one is sued, by occasion of Tuto...
# 948   @SECT. @I.] THE ISLES OF GREECE. 4+3 CCCXLIV....
#
#                                             GS_aligned   dirname
# 889   @@@@@@@@@@@@@@@@@@@@@@@@@ Scapin. Well,@ Sir,...  en1_2019
# 893    The PREFACE. If the Souls of all Mankind be ...  en1_2019
# 894    ( 99 ) betwixt our condition, and that of th...  en1_2019
# 918    (10) skilfull in all the learning of the Ægy...  en1_2019
# 919    86 A Mison head, for@ the@ croſs is left@@ ...  en1_2019
# 927    PREFACE. vii Abp. Trench could tell us nothi...  en1_2019
# 929                                                @\n  en1_2019
# 932    [ 89 ] out shutting out and Retraction of th...  en1_2019
# 933   @@@@@@@@@@@@@@@@@@@@@@ Se@tio Tertia.@@@@@@@...  en1_2019
# 938    24 CHARACTERS An vnworthie Knight. 15. A wor...  en1_2019
# 939    ( 85 ) when one is sued, by occaffon of Tuto...  en1_2019
# 948    443 * From Dun Juan, canto iii.@@@@ CCCXLIV....  en1_2019

# %% [markdown]
# ### Remove duplicate rows

# %%
db = db.drop_duplicates("OCR_toInput")
print("Length after removing duplicates: {}".format(len(db)))
db.head()
# Out:
# Length after removing duplicates: 951
#   index                                        OCR_toInput  \
# 0   289   BK. III. 364 AN ENGLISH ANTHOLOGY. Over many ...
# 1   504   47 K0BEET THE DETJYLL. How God sent an aunged...
# 2   262   bk. Ill 322 AN ENGLISH ANTHOLOGY. The and The...
# 3   276   SECT. IV. SWEET AUBURN. 341 E'en children fol...
# 4   510   ROBERT THE DETJYLE. 53 shewed hym of this bef...
#
#                                          OCR_aligned  \
# 0   BK. III. 364 AN ENGLISH ANTHOLOGY. Over many ...
# 1   47 K0BEET THE DETJYLL. How God sent an aunge@...
# 2   bk. Ill 322 AN ENGLISH ANTHOLOGY. The and The...
# 3   SECT. IV. SWEET AUBURN. 341 E'en children fol...
# 4   ROBERT THE DETJYLE. 53 shewed hym of this bef...
#
#                                           GS_aligned             dirname
# 0   ####################################### many ...  eng_monograph_2017
# 1   ########################## God sent an aungel...  eng_monograph_2017
# 2   #############################################...  eng_monograph_2017
# 3   ################################ children fol...  eng_monograph_2017
# 4   ############################# hym of this bef...  eng_monograph_2017

# %% [markdown]
# ## Sentencizer

# %%
db_sentence = pd.DataFrame(columns=["doc_index", "sent_index", "OCR_aligned", "GS_aligned", "begin_index"])
counter = 0

for i_row, myrow in db.iterrows():
    if np.mod(counter, 100) == 0: print("X", end="")
    list_sentence_offsets = []

    for paragraph in segmenter.process(myrow["GS_aligned"]):
        for sentence in paragraph:
            list_sentence_offsets.append(sentence[0].offset)

    for x in range(len(list_sentence_offsets)):
        counter += 1
        begSentence = list_sentence_offsets[x]
        try:
            endSentence = list_sentence_offsets[x+1]
        except IndexError:
            endSentence = len(myrow["GS_aligned"])
        ocr_sentence = myrow["OCR_aligned"][begSentence - 1 : endSentence - 1]
        gs_sentence = myrow["GS_aligned"][begSentence - 1 : endSentence - 1]
        db_sentence.loc[counter] = ["{}_{}".format(myrow["dirname"], myrow["index"]), 
                                    "{}_{}_{}".format(myrow["dirname"], myrow["index"], begSentence),
                                    ocr_sentence, gs_sentence, 
                                    begSentence-1]
# Out:
# XXXXXXXXXXXX

# %%
db_sentence.head()
# Out:
#                 doc_index                  sent_index  \
# 1  eng_monograph_2017_289    eng_monograph_2017_289_1
# 2  eng_monograph_2017_289  eng_monograph_2017_289_161
# 3  eng_monograph_2017_289  eng_monograph_2017_289_219
# 4  eng_monograph_2017_289  eng_monograph_2017_289_341
# 5  eng_monograph_2017_289  eng_monograph_2017_289_464
#
#                                          OCR_aligned  \
# 1   BK. III. 364 AN ENGLISH ANTHOLOGY. Over many ...
# 2   Now they look abroad to see, Now return and w...
# 3   Pitying, I dropped a tear But I saw a glow-wo...
# 4   I am set to light the ground, While the beetl...
# 5                                          ' -Blake.
#
#                                           GS_aligned begin_index
# 1   ####################################### many ...           0
# 2   Now they look abroad to see, Now return and w...         160
# 3   Pitying, I dropped a tear But I saw a glow-wo...         218
# 4   I am set to light the ground, While the beetl...         340
# 5                                          ' -Blake.         463

# %% [markdown]
# ## Save DataFrame

# %%
#db.to_pickle("db_ICDAR.pkl")
db_sentence.to_pickle("db_sentence_ICDAR_new.pkl")
